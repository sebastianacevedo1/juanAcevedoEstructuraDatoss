# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastianacevedo1/juanAcevedoEstructuraDatoss/blob/main/tarea_arbolesb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tarea arboles binarios
#
# Juan Sebatian acevedo Muñoz
# 925783
#
#
#
# a. 15,6,18,3,7,17,20,2,4,13,9

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Definir la clase de nodo para el árbol binario de búsqueda
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# Función para insertar valores en el árbol binario de búsqueda
def insert(root, value):
    if root is None:
        return Node(value)
    if value < root.value:
        root.left = insert(root.left, value)
    else:
        root.right = insert(root.right, value)
    return root

# Crear el árbol con los valores especificados
values = [15, 6, 18, 3, 7, 17, 20, 2, 4, 13, 9]
root = None
for value in values:
    root = insert(root, value)

# Crear el gráfico del árbol binario de búsqueda
def add_edges(graph, node):
    if node is not None:
        if node.left is not None:
            graph.add_edge(node.value, node.left.value)
            add_edges(graph, node.left)
        if node.right is not None:
            graph.add_edge(node.value, node.right.value)
            add_edges(graph, node.right)

# Crear el gráfico y agregar nodos y aristas
G = nx.DiGraph()
add_edges(G, root)

# Definir posiciones específicas para cada nodo, imitando la disposición de la imagen
pos = {
    15: (0, 3),
    6: (-1.2, 2),
    18: (1.2, 2),
    3: (-1.8, 1),
    7: (-0.8, 1),
    17: (0.8, 1),
    20: (1.8, 1),
    2: (-2.5, 0),
    4: (-1.5, 0),
    9: (-0.8, -1),
    13: (-0.2, 0)
}

# Dibujar el gráfico
plt.figure(figsize=(10, 7))
nx.draw(G, pos, with_labels=True, node_size=1000, node_color="#c63d20", font_size=15, font_weight="bold", arrows=True)
plt.title("Árbol Binario de Búsqueda")
plt.show()

# %% [markdown]
# b. 25,15,50,10,22,35,70,4,12,18,24,31,44,66,90

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Definir la clase de nodo para el árbol binario de búsqueda
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# Función para insertar valores en el árbol binario de búsqueda
def insert(root, value):
    if root is None:
        return Node(value)
    if value < root.value:
        root.left = insert(root.left, value)
    else:
        root.right = insert(root.right, value)
    return root

# Crear el árbol con los valores especificados
values = [25, 15, 50, 10, 22, 35, 70, 4, 12, 18, 24, 31, 44, 66, 90]
root = None
for value in values:
    root = insert(root, value)

# Crear el gráfico del árbol binario de búsqueda
def add_edges(graph, node):
    if node is not None:
        if node.left is not None:
            graph.add_edge(node.value, node.left.value)
            add_edges(graph, node.left)
        if node.right is not None:
            graph.add_edge(node.value, node.right.value)
            add_edges(graph, node.right)

# Crear el gráfico y agregar nodos y aristas
G = nx.DiGraph()
add_edges(G, root)

# Definir posiciones específicas para cada nodo, imitando la disposición de la imagen
pos = {
    25: (0, 3),
    15: (-1.2, 2),
    50: (1.2, 2),
    10: (-1.8, 1),
    22: (-0.8, 1),
    35: (0.8, 1),
    70: (1.8, 1),
    4: (-2.5, 0),
    12: (-1.5, 0),
    18: (-1, 0),
    24: (-0.2, 0),
    31: (0.2, 0),
    44: (1.2, 0),
    66: (1.5, 0),
    90: (2.5, 0)
}

# Dibujar el gráfico
plt.figure(figsize=(10, 7))
nx.draw(G, pos, with_labels=True, node_size=1000, node_color="#36efd9", font_size=15, font_weight="bold", arrows=True)
plt.title("Árbol Binario de Búsqueda")
plt.show()

# %% [markdown]
# c. 30,20,40,10,25,35,50

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Definir la clase de nodo para el árbol binario de búsqueda
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# Función para insertar valores en el árbol binario de búsqueda
def insert(root, value):
    if root is None:
        return Node(value)
    if value < root.value:
        root.left = insert(root.left, value)
    else:
        root.right = insert(root.right, value)
    return root

# Crear el árbol con los valores especificados
values = [30, 20, 40, 10, 25, 35, 50]
root = None
for value in values:
    root = insert(root, value)

# Crear el gráfico del árbol binario de búsqueda
def add_edges(graph, node):
    if node is not None:
        if node.left is not None:
            graph.add_edge(node.value, node.left.value)
            add_edges(graph, node.left)
        if node.right is not None:
            graph.add_edge(node.value, node.right.value)
            add_edges(graph, node.right)

# Crear el gráfico y agregar nodos y aristas
G = nx.DiGraph()
add_edges(G, root)

# Definir posiciones específicas para cada nodo, imitando la disposición de la imagen
pos = {
    30: (0, 3),
    20: (-1.2, 2),
    40: (1.2, 2),
    10: (-1.8, 1),
    25: (-0.8, 1),
    35: (0.8, 1),
    50: (1.8, 1)
}

# Dibujar el gráfico
plt.figure(figsize=(10, 7))
nx.draw(G, pos, with_labels=True, node_size=1000, node_color="#230ef0", font_size=15, font_weight="bold", arrows=True)
plt.title("Árbol Binario de Búsqueda")
plt.show()

# %% [markdown]
# d. 27,14,35,10,19,31,42,9,12,18,20,30,33,38,45

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Definir la clase de nodo para el árbol binario de búsqueda
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# Función para insertar valores en el árbol binario de búsqueda
def insert(root, value):
    if root is None:
        return Node(value)
    if value < root.value:
        root.left = insert(root.left, value)
    else:
        root.right = insert(root.right, value)
    return root

# Crear el árbol con los valores especificados
values = [27, 14, 35, 10, 19, 31, 42, 9, 12, 18, 20, 30, 33, 38, 45]
root = None
for value in values:
    root = insert(root, value)

# Crear el gráfico del árbol binario de búsqueda
def add_edges(graph, node):
    if node is not None:
        if node.left is not None:
            graph.add_edge(node.value, node.left.value)
            add_edges(graph, node.left)
        if node.right is not None:
            graph.add_edge(node.value, node.right.value)
            add_edges(graph, node.right)

# Crear el gráfico y agregar nodos y aristas
G = nx.DiGraph()
add_edges(G, root)

# Definir posiciones específicas para cada nodo, imitando la disposición de la imagen
pos = {
    27: (0, 3),
    14: (-1.2, 2),
    35: (1.2, 2),
    10: (-1.8, 1),
    19: (-0.8, 1),
    31: (0.8, 1),
    42: (1.8, 1),
    9: (-2.5, 0),
    12: (-1.5, 0),
    18: (-1, 0),
    20: (-0.2, 0),
    30: (0.2, 0),
    33: (1.2, 0),
    38: (1.5, 0),
    45: (2.5, 0)
}

# Dibujar el gráfico
plt.figure(figsize=(10, 7))
nx.draw(G, pos, with_labels=True, node_size=1000, node_color="#6ce166", font_size=15, font_weight="bold", arrows=True)
plt.title("Árbol Binario de Búsqueda")
plt.show()
